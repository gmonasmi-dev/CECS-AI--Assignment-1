# %% [markdown]
# <a href="https://colab.research.google.com/github/gmonasmi-dev/CECS-AI--Assignment-1/blob/main/hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Dr.S")
# Out:
# Hello Dr.S
